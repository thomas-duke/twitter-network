# %%
from networkx.algorithms.link_analysis import *
import networkx as nx

# %%
# %reload_kedro
page_rank = io.load('page_rank')
katz = io.load('katz')
edges = io.load('edges_train')
# Out:
# 2019-07-02 11:01:13,675 - INFO - ** Kedro project Twitter Network
# 2019-07-02 11:01:13,678 - INFO - Loading: /Users/tomduke/Documents/Academic/MBusA/Modules/M3 - Advanced Analytics/Machine Learning/twitter-network/conf/base/logging.yml
# 2019-07-02 11:01:13,689 - INFO - Loading: /Users/tomduke/Documents/Academic/MBusA/Modules/M3 - Advanced Analytics/Machine Learning/twitter-network/conf/base/catalog.yml
# 2019-07-02 11:01:13,711 - INFO - Loading: /Users/tomduke/Documents/Academic/MBusA/Modules/M3 - Advanced Analytics/Machine Learning/twitter-network/conf/base/credentials.yml
# 2019-07-02 11:01:13,714 - INFO - Loading: /Users/tomduke/Documents/Academic/MBusA/Modules/M3 - Advanced Analytics/Machine Learning/twitter-network/conf/base/parameters.yml
# 2019-07-02 11:01:13,726 - INFO - Defined global variables proj_dir, proj_name, conf and io
# 2019-07-02 11:01:13,727 - INFO - Loading data from `page_rank` (PickleLocalDataSet)...
# ...

# %%
edges
# Out:
# [('2975979', '4568338'),
#  ('1169874', '4283401'),
#  ('3674016', '1732367'),
#  ('4113405', '3802450'),
#  ('4245341', '2318026'),
#  ('1041928', '1685001'),
#  ('3602451', '1123949'),
#  ('4371955', '163021'),
#  ('3694046', '344072'),
#  ('2359631', '3635970'),
#  ('4675165', '1119747'),
#  ('3385687', '970774'),
#  ('2719963', '4180652'),
#  ('2887037', '1959937'),
#  ('430251', '3762202'),
#  ('4022436', '3557116'),
#  ('4319074', '478134'),
#  ('3210136', '2921510'),
#  ('4187899', '3903505'),
#  ('264520', '3402178'),
#  ('4205304', '2989221'),
#  ('373567', '2673193'),
#  ('2395078', '4631211'),
#  ('2636592', '4797908'),
#  ('3920749', '4734474'),
#  ('3947401', '2618924'),
#  ('3146046', '161949'),
#  ('1213060', '4449857'),
#  ('1095521', '3638419'),
#  ('2808644', '413931'),
#  ('1204056', '2164686'),
#  ('3228963', '4345836'),
#  ('3213568', '4860786'),
#  ('520324', '2122753'),
#  ('2026334', '1984005'),
#  ('1382021', '1048821'),
#  ('495684', '3744513'),
# ...

# %%
page_rank[int('2975979')]
# Out:
# 7.42360704873877e-07

# %%
katz[int('2975979')]
# Out:
# 0.0009703829328358759
